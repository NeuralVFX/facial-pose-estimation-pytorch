# %% [markdown]
# # Imports

# %%
import math
import time
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as opt

import onnx
from onnx import optimizer

from util import losses as loss
from util import loaders as load
from util import training as train
from util import helpers as helper
from models import networks as n

# %% [markdown]
# # Setup Network, Data Generator, Optimizer, Losses

# %%
############################################################################
# Network
############################################################################

res_net = n.CustomResnet(51)
res_net.cuda()

############################################################################
# Loss
############################################################################

mse_crit = nn.MSELoss()
point_crit = loss.PointLoss().cuda()

############################################################################
# Optimizer
############################################################################

lr = 1e-3
lr_array = np.array([lr/100,lr/10,lr])
lr_groups = res_net.lr_groups()
opt_params = [{"params":lr_groups[0].parameters(),"lr":lr_array[0]},
              {"params":lr_groups[1].parameters(),"lr":lr_array[1]},
              {"params":lr_groups[2].parameters(),"lr":lr_array[2]}]

adam_opt = opt.Adam(opt_params,betas=(0.9, 0.999),weight_decay= .0001)

############################################################################
# Data Generators
############################################################################

transform = load.NormDenorm([.5, .5, .5], [.5, .5, .5])
train_data= load.LandMarkGenerator( transform, output_res=96, size = 10000, rand_rot = .7)
test_data = load.LandMarkGenerator( transform, output_res=96, size = 300, rand_rot = .7)   
batch_size = 8
mtrain = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=8, shuffle=True, drop_last=True)
mtest  = torch.utils.data.DataLoader(test_data, batch_size=batch_size, num_workers=8, shuffle=False, drop_last=True)

############################################################################
# Train Dictionary
############################################################################

train_dict = {
    "train_loader":mtrain,
    "test_loader":mtest,
    "opt":adam_opt,
    "net":res_net,
    "mse_crit":mse_crit,
    "point_crit":point_crit
}

# %% [markdown]
# # Example Training Data

# %%
% matplotlib inline
helper.view_dataset(train_data,transform)

# %% [markdown]
# # Training Round One

# %%
lr = 1e-3  
lr_array = np.array([lr/5,lr/3,lr])

for i in range(1,7):
    print (f'Run #{i}')
    epoch_count = i
    lr_list = train.set_lr_sched(epoch_count,mtrain.__len__()//batch_size,2.0)
    helper.lr_preview(lr_list)
    freeze = (i-1)*2
    if i == 4:
        freeze = 100
    train.one_run(train_dict,freeze,lr_list,lr_array)
# Out:
# Run #1
# Layer 0 : Grad:False
# Layer 1 : Grad:False
# Layer 2 : Grad:False
# Layer 3 : Grad:False
# Layer 4 : Grad:False
# Layer 5 : Grad:False
# train mse_loss: 0.051750548183918   train point_loss: 0.04908210039138794
# test mse_loss: 0.04835587739944458   test point_loss: 0.04594409465789795
# Done
# Run #2
# Layer 0 : Grad:False
# Layer 1 : Grad:False
# Layer 2 : Grad:False
# Layer 3 : Grad:False
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.04786049947142601   train point_loss: 0.040583666414022446
# test mse_loss: 0.045933712273836136   test point_loss: 0.03631171956658363
# Done
# Run #3
# Layer 0 : Grad:False
# Layer 1 : Grad:False
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f1d7ebec240>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.0425243154168129   train point_loss: 0.033182475715875626
# test mse_loss: 0.03731021657586098   test point_loss: 0.02685464732348919
# Done
# Run #4
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.03843144699931145   train point_loss: 0.029510751366615295
# test mse_loss: 0.03981615602970123   test point_loss: 0.034098923206329346
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f1d942e5f98>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.034854210913181305   train point_loss: 0.027139494195580482
# test mse_loss: 0.032107748091220856   test point_loss: 0.022796930745244026
# Done
# Run #5
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.03353337571024895   train point_loss: 0.02639196440577507
# test mse_loss: 0.03774639591574669   test point_loss: 0.028648514300584793
# train mse_loss: 0.03210490569472313   train point_loss: 0.025004753842949867
# test mse_loss: 0.034985415637493134   test point_loss: 0.02849246747791767
# train mse_loss: 0.031726446002721786   train point_loss: 0.02532857283949852
# test mse_loss: 0.028569111600518227   test point_loss: 0.02278200536966324
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f1d94237438>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 58, in detach
#     return reduction.recv_handle(conn)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/reduction.py", line 182, in recv_handle
#     return recvfds(s, 1)[0]
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/reduction.py", line 153, in recvfds
#     msg, ancdata, flags, addr = sock.recvmsg(1, socket.CMSG_LEN(bytes_size))
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.02857850305736065   train point_loss: 0.021819623187184334
# test mse_loss: 0.027098771184682846   test point_loss: 0.02045649103820324
# Done
# Run #6
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.029771212488412857   train point_loss: 0.023751653730869293
# test mse_loss: 0.03166588768362999   test point_loss: 0.026130134239792824
# train mse_loss: 0.028766492381691933   train point_loss: 0.02312217839062214
# test mse_loss: 0.030753815546631813   test point_loss: 0.026418525725603104
# train mse_loss: 0.029213769361376762   train point_loss: 0.02392595447599888
# test mse_loss: 0.026401476934552193   test point_loss: 0.02205909974873066
# train mse_loss: 0.026430699974298477   train point_loss: 0.020903080701828003
# test mse_loss: 0.029443087056279182   test point_loss: 0.023161226883530617
# train mse_loss: 0.02869502268731594   train point_loss: 0.02391362003982067
# test mse_loss: 0.027445564046502113   test point_loss: 0.022906381636857986
# train mse_loss: 0.02692721225321293   train point_loss: 0.02229095809161663
# test mse_loss: 0.026119478046894073   test point_loss: 0.021730739623308182
# train mse_loss: 0.025176672264933586   train point_loss: 0.020214399322867393
# test mse_loss: 0.022891033440828323   test point_loss: 0.018397103995084763
# train mse_loss: 0.023838626220822334   train point_loss: 0.018818775191903114
# test mse_loss: 0.02232716791331768   test point_loss: 0.017603442072868347
# Done

# %%
helper.view_predictions(res_net,train_data)
helper.export_onnx(res_net,'output/run_1')
# Out:
# graph(%0 : Float(1, 3, 96, 96)
#       %1 : Float(64, 3, 7, 7)
#       %2 : Float(64)
#       %3 : Float(64)
#       %4 : Float(64)
#       %5 : Float(64)
#       %6 : Long()
#       %7 : Float(64, 64, 3, 3)
#       %8 : Float(64)
#       %9 : Float(64)
#       %10 : Float(64)
#       %11 : Float(64)
#       %12 : Long()
#       %13 : Float(64, 64, 3, 3)
#       %14 : Float(64)
#       %15 : Float(64)
#       %16 : Float(64)
#       %17 : Float(64)
#       %18 : Long()
#       %19 : Float(64, 64, 3, 3)
#       %20 : Float(64)
#       %21 : Float(64)
#       %22 : Float(64)
#       %23 : Float(64)
#       %24 : Long()
#       %25 : Float(64, 64, 3, 3)
#       %26 : Float(64)
#       %27 : Float(64)
#       %28 : Float(64)
#       %29 : Float(64)
#       %30 : Long()
#       %31 : Float(64, 64, 3, 3)
#       %32 : Float(64)
#       %33 : Float(64)
#       %34 : Float(64)
#       %35 : Float(64)
#       %36 : Long()
#       %37 : Float(64, 64, 3, 3)
#       %38 : Float(64)
#       %39 : Float(64)
#       %40 : Float(64)
#       %41 : Float(64)
#       %42 : Long()
#       %43 : Float(128, 64, 3, 3)
#       %44 : Float(128)
#       %45 : Float(128)
#       %46 : Float(128)
#       %47 : Float(128)
#       %48 : Long()
#       %49 : Float(128, 128, 3, 3)
#       %50 : Float(128)
#       %51 : Float(128)
#       %52 : Float(128)
#       %53 : Float(128)
#       %54 : Long()
#       %55 : Float(128, 64, 1, 1)
#       %56 : Float(128)
#       %57 : Float(128)
#       %58 : Float(128)
#       %59 : Float(128)
#       %60 : Long()
#       %61 : Float(128, 128, 3, 3)
#       %62 : Float(128)
#       %63 : Float(128)
#       %64 : Float(128)
#       %65 : Float(128)
#       %66 : Long()
#       %67 : Float(128, 128, 3, 3)
#       %68 : Float(128)
#       %69 : Float(128)
#       %70 : Float(128)
#       %71 : Float(128)
#       %72 : Long()
#       %73 : Float(128, 128, 3, 3)
#       %74 : Float(128)
#       %75 : Float(128)
#       %76 : Float(128)
#       %77 : Float(128)
#       %78 : Long()
#       %79 : Float(128, 128, 3, 3)
#       %80 : Float(128)
#       %81 : Float(128)
#       %82 : Float(128)
#       %83 : Float(128)
#       %84 : Long()
#       %85 : Float(128, 128, 3, 3)
#       %86 : Float(128)
#       %87 : Float(128)
#       %88 : Float(128)
#       %89 : Float(128)
#       %90 : Long()
#       %91 : Float(128, 128, 3, 3)
#       %92 : Float(128)
#       %93 : Float(128)
#       %94 : Float(128)
#       %95 : Float(128)
#       %96 : Long()
#       %97 : Float(51, 512)
#       %98 : Float(51)) {
#   %99 : Float(1, 64, 48, 48) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[2, 2]](%0, %1), scope: CustomResnet/Sequential[resnet]/Conv2d[0]
#   %100 : Float(1, 64, 48, 48) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%99, %2, %3, %4, %5), scope: CustomResnet/Sequential[resnet]/BatchNorm2d[1]
#   %101 : Float(1, 64, 48, 48) = onnx::Relu(%100), scope: CustomResnet/Sequential[resnet]/ReLU[2]
#   %102 : Float(1, 64, 24, 24) = onnx::MaxPool[kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%101), scope: CustomResnet/Sequential[resnet]/MaxPool2d[3]
#   %103 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%102, %7), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/Conv2d[conv1]
#   %104 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%103, %8, %9, %10, %11), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/BatchNorm2d[bn1]
#   %105 : Float(1, 64, 24, 24) = onnx::Relu(%104), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/ReLU[relu]
#   %106 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%105, %13), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/Conv2d[conv2]
#   %107 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%106, %14, %15, %16, %17), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/BatchNorm2d[bn2]
#   %108 : Float(1, 64, 24, 24) = onnx::Add(%107, %102), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]
#   %109 : Float(1, 64, 24, 24) = onnx::Relu(%108), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/ReLU[relu]
#   %110 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%109, %19), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/Conv2d[conv1]
#   %111 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%110, %20, %21, %22, %23), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/BatchNorm2d[bn1]
#   %112 : Float(1, 64, 24, 24) = onnx::Relu(%111), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/ReLU[relu]
#   %113 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%112, %25), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/Conv2d[conv2]
#   %114 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%113, %26, %27, %28, %29), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/BatchNorm2d[bn2]
#   %115 : Float(1, 64, 24, 24) = onnx::Add(%114, %109), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]
#   %116 : Float(1, 64, 24, 24) = onnx::Relu(%115), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/ReLU[relu]
#   %117 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%116, %31), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/Conv2d[conv1]
#   %118 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%117, %32, %33, %34, %35), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/BatchNorm2d[bn1]
#   %119 : Float(1, 64, 24, 24) = onnx::Relu(%118), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/ReLU[relu]
#   %120 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%119, %37), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/Conv2d[conv2]
#   %121 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%120, %38, %39, %40, %41), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/BatchNorm2d[bn2]
#   %122 : Float(1, 64, 24, 24) = onnx::Add(%121, %116), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]
#   %123 : Float(1, 64, 24, 24) = onnx::Relu(%122), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/ReLU[relu]
#   %124 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%123, %43), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Conv2d[conv1]
#   %125 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%124, %44, %45, %46, %47), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/BatchNorm2d[bn1]
#   %126 : Float(1, 128, 12, 12) = onnx::Relu(%125), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/ReLU[relu]
#   %127 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%126, %49), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Conv2d[conv2]
#   %128 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%127, %50, %51, %52, %53), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/BatchNorm2d[bn2]
#   %129 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%123, %55), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]
#   %130 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%129, %56, %57, %58, %59), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]
#   %131 : Float(1, 128, 12, 12) = onnx::Add(%128, %130), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]
#   %132 : Float(1, 128, 12, 12) = onnx::Relu(%131), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/ReLU[relu]
#   %133 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%132, %61), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/Conv2d[conv1]
#   %134 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%133, %62, %63, %64, %65), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/BatchNorm2d[bn1]
#   %135 : Float(1, 128, 12, 12) = onnx::Relu(%134), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/ReLU[relu]
#   %136 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%135, %67), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/Conv2d[conv2]
#   %137 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%136, %68, %69, %70, %71), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/BatchNorm2d[bn2]
#   %138 : Float(1, 128, 12, 12) = onnx::Add(%137, %132), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]
#   %139 : Float(1, 128, 12, 12) = onnx::Relu(%138), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/ReLU[relu]
#   %140 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%139, %73), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/Conv2d[conv1]
#   %141 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%140, %74, %75, %76, %77), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/BatchNorm2d[bn1]
#   %142 : Float(1, 128, 12, 12) = onnx::Relu(%141), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/ReLU[relu]
#   %143 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%142, %79), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/Conv2d[conv2]
#   %144 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%143, %80, %81, %82, %83), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/BatchNorm2d[bn2]
#   %145 : Float(1, 128, 12, 12) = onnx::Add(%144, %139), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]
#   %146 : Float(1, 128, 12, 12) = onnx::Relu(%145), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/ReLU[relu]
#   %147 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%146, %85), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/Conv2d[conv1]
#   %148 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%147, %86, %87, %88, %89), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/BatchNorm2d[bn1]
#   %149 : Float(1, 128, 12, 12) = onnx::Relu(%148), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/ReLU[relu]
#   %150 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%149, %91), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/Conv2d[conv2]
#   %151 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%150, %92, %93, %94, %95), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/BatchNorm2d[bn2]
#   %152 : Float(1, 128, 12, 12) = onnx::Add(%151, %146), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]
#   %153 : Float(1, 128, 12, 12) = onnx::Relu(%152), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/ReLU[relu]
#   %154 : Dynamic = onnx::Pad[mode=constant, pads=[0, 0, 2, 2, 0, 0, 2, 2], value=0](%153), scope: CustomResnet/ResHead[reshead]/AvgPool2d[av_pool]
#   %155 : Float(1, 128, 2, 2) = onnx::AveragePool[kernel_shape=[8, 8], pads=[0, 0, 0, 0], strides=[6, 6]](%154), scope: CustomResnet/ResHead[reshead]/AvgPool2d[av_pool]
#   %156 : Dynamic = onnx::Constant[value=  -1  512 [ CPULongTensor{2} ]](), scope: CustomResnet/ResHead[reshead]
#   %157 : Float(1, 512) = onnx::Reshape(%155, %156), scope: CustomResnet/ResHead[reshead]
#   %158 : Float(1, 51) = onnx::Gemm[alpha=1, beta=1, broadcast=1, transB=1](%157, %97, %98), scope: CustomResnet/ResHead[reshead]/Linear[linear]
#   %159 : Dynamic = onnx::Constant[value= -1  51 [ CPULongTensor{2} ]](), scope: CustomResnet
#   %output1 : Float(1, 51) = onnx::Reshape(%158, %159), scope: CustomResnet
#   return (%output1);
# }

# %% [markdown]
# # Training Round Two

# %%
lr = 1e-4  
lr_array = np.array([lr/5,lr/3,lr])

for i in range(1,7):
    print (f'Run #{i}')
    epoch_count = i
    lr_list = train.set_lr_sched(epoch_count,mtrain.__len__()//batch_size,2.0)
    helper.lr_preview(lr_list)

    freeze = 100
    train.one_run(train_dict,freeze,lr_list,lr_array)
# Out:
# Run #1
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.0237955953925848   train point_loss: 0.019058534875512123
# test mse_loss: 0.023640239611268044   test point_loss: 0.01867005228996277
# Done
# Run #2
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f1d93cc10f0>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
# train mse_loss: 0.023827388882637024   train point_loss: 0.018615523353219032
# test mse_loss: 0.02315566875040531   test point_loss: 0.018762940540909767
# Done
# Run #3
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.023348595947027206   train point_loss: 0.018514789640903473
# test mse_loss: 0.021875586360692978   test point_loss: 0.017661722376942635
# Done
# Run #4
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.02318233996629715   train point_loss: 0.018421750515699387
# test mse_loss: 0.02256559394299984   test point_loss: 0.018866581842303276
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f1d93c49240>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 494, in Client
#     deliver_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 722, in deliver_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.023217402398586273   train point_loss: 0.018270352855324745
# test mse_loss: 0.022515274584293365   test point_loss: 0.0171598382294178
# Done
# Run #5
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.023095624521374702   train point_loss: 0.018247276544570923
# test mse_loss: 0.022099802270531654   test point_loss: 0.017637664452195168
# train mse_loss: 0.02293562889099121   train point_loss: 0.01810186170041561
# test mse_loss: 0.02243679203093052   test point_loss: 0.0187253225594759
# train mse_loss: 0.022943587973713875   train point_loss: 0.018077688291668892
# test mse_loss: 0.02163311280310154   test point_loss: 0.01738940365612507
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f1d7edbbb70>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 58, in detach
#     return reduction.recv_handle(conn)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/reduction.py", line 182, in recv_handle
#     return recvfds(s, 1)[0]
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/reduction.py", line 153, in recvfds
#     msg, ancdata, flags, addr = sock.recvmsg(1, socket.CMSG_LEN(bytes_size))
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.022435346618294716   train point_loss: 0.017718713730573654
# test mse_loss: 0.022160597145557404   test point_loss: 0.01797192171216011
# Done
# Run #6
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.022553512826561928   train point_loss: 0.017926158383488655
# test mse_loss: 0.023250408470630646   test point_loss: 0.018015574663877487
# train mse_loss: 0.022466588765382767   train point_loss: 0.017812877893447876
# test mse_loss: 0.02248428389430046   test point_loss: 0.018007462844252586
# train mse_loss: 0.022396108135581017   train point_loss: 0.01789749227464199
# test mse_loss: 0.021282397210597992   test point_loss: 0.016168266534805298
# train mse_loss: 0.022070491686463356   train point_loss: 0.017387792468070984
# test mse_loss: 0.02127997949719429   test point_loss: 0.016964174807071686
# train mse_loss: 0.022253936156630516   train point_loss: 0.01787133701145649
# test mse_loss: 0.021036749705672264   test point_loss: 0.01693671941757202
# train mse_loss: 0.021902913227677345   train point_loss: 0.01752636954188347
# test mse_loss: 0.020683636888861656   test point_loss: 0.016335608437657356
# train mse_loss: 0.021790120750665665   train point_loss: 0.01730535551905632
# test mse_loss: 0.020727504044771194   test point_loss: 0.01670769602060318
# train mse_loss: 0.021645281463861465   train point_loss: 0.01706809550523758
# test mse_loss: 0.020329898223280907   test point_loss: 0.016441304236650467
# Done

# %%
helper.view_predictions(res_net,train_data)
helper.export_onnx(res_net,'output/run_2')
# Out:
# graph(%0 : Float(1, 3, 96, 96)
#       %1 : Float(64, 3, 7, 7)
#       %2 : Float(64)
#       %3 : Float(64)
#       %4 : Float(64)
#       %5 : Float(64)
#       %6 : Long()
#       %7 : Float(64, 64, 3, 3)
#       %8 : Float(64)
#       %9 : Float(64)
#       %10 : Float(64)
#       %11 : Float(64)
#       %12 : Long()
#       %13 : Float(64, 64, 3, 3)
#       %14 : Float(64)
#       %15 : Float(64)
#       %16 : Float(64)
#       %17 : Float(64)
#       %18 : Long()
#       %19 : Float(64, 64, 3, 3)
#       %20 : Float(64)
#       %21 : Float(64)
#       %22 : Float(64)
#       %23 : Float(64)
#       %24 : Long()
#       %25 : Float(64, 64, 3, 3)
#       %26 : Float(64)
#       %27 : Float(64)
#       %28 : Float(64)
#       %29 : Float(64)
#       %30 : Long()
#       %31 : Float(64, 64, 3, 3)
#       %32 : Float(64)
#       %33 : Float(64)
#       %34 : Float(64)
#       %35 : Float(64)
#       %36 : Long()
#       %37 : Float(64, 64, 3, 3)
#       %38 : Float(64)
#       %39 : Float(64)
#       %40 : Float(64)
#       %41 : Float(64)
#       %42 : Long()
#       %43 : Float(128, 64, 3, 3)
#       %44 : Float(128)
#       %45 : Float(128)
#       %46 : Float(128)
#       %47 : Float(128)
#       %48 : Long()
#       %49 : Float(128, 128, 3, 3)
#       %50 : Float(128)
#       %51 : Float(128)
#       %52 : Float(128)
#       %53 : Float(128)
#       %54 : Long()
#       %55 : Float(128, 64, 1, 1)
#       %56 : Float(128)
#       %57 : Float(128)
#       %58 : Float(128)
#       %59 : Float(128)
#       %60 : Long()
#       %61 : Float(128, 128, 3, 3)
#       %62 : Float(128)
#       %63 : Float(128)
#       %64 : Float(128)
#       %65 : Float(128)
#       %66 : Long()
#       %67 : Float(128, 128, 3, 3)
#       %68 : Float(128)
#       %69 : Float(128)
#       %70 : Float(128)
#       %71 : Float(128)
#       %72 : Long()
#       %73 : Float(128, 128, 3, 3)
#       %74 : Float(128)
#       %75 : Float(128)
#       %76 : Float(128)
#       %77 : Float(128)
#       %78 : Long()
#       %79 : Float(128, 128, 3, 3)
#       %80 : Float(128)
#       %81 : Float(128)
#       %82 : Float(128)
#       %83 : Float(128)
#       %84 : Long()
#       %85 : Float(128, 128, 3, 3)
#       %86 : Float(128)
#       %87 : Float(128)
#       %88 : Float(128)
#       %89 : Float(128)
#       %90 : Long()
#       %91 : Float(128, 128, 3, 3)
#       %92 : Float(128)
#       %93 : Float(128)
#       %94 : Float(128)
#       %95 : Float(128)
#       %96 : Long()
#       %97 : Float(51, 512)
#       %98 : Float(51)) {
#   %99 : Float(1, 64, 48, 48) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[2, 2]](%0, %1), scope: CustomResnet/Sequential[resnet]/Conv2d[0]
#   %100 : Float(1, 64, 48, 48) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%99, %2, %3, %4, %5), scope: CustomResnet/Sequential[resnet]/BatchNorm2d[1]
#   %101 : Float(1, 64, 48, 48) = onnx::Relu(%100), scope: CustomResnet/Sequential[resnet]/ReLU[2]
#   %102 : Float(1, 64, 24, 24) = onnx::MaxPool[kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%101), scope: CustomResnet/Sequential[resnet]/MaxPool2d[3]
#   %103 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%102, %7), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/Conv2d[conv1]
#   %104 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%103, %8, %9, %10, %11), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/BatchNorm2d[bn1]
#   %105 : Float(1, 64, 24, 24) = onnx::Relu(%104), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/ReLU[relu]
#   %106 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%105, %13), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/Conv2d[conv2]
#   %107 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%106, %14, %15, %16, %17), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/BatchNorm2d[bn2]
#   %108 : Float(1, 64, 24, 24) = onnx::Add(%107, %102), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]
#   %109 : Float(1, 64, 24, 24) = onnx::Relu(%108), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/ReLU[relu]
#   %110 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%109, %19), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/Conv2d[conv1]
#   %111 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%110, %20, %21, %22, %23), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/BatchNorm2d[bn1]
#   %112 : Float(1, 64, 24, 24) = onnx::Relu(%111), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/ReLU[relu]
#   %113 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%112, %25), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/Conv2d[conv2]
#   %114 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%113, %26, %27, %28, %29), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/BatchNorm2d[bn2]
#   %115 : Float(1, 64, 24, 24) = onnx::Add(%114, %109), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]
#   %116 : Float(1, 64, 24, 24) = onnx::Relu(%115), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/ReLU[relu]
#   %117 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%116, %31), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/Conv2d[conv1]
#   %118 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%117, %32, %33, %34, %35), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/BatchNorm2d[bn1]
#   %119 : Float(1, 64, 24, 24) = onnx::Relu(%118), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/ReLU[relu]
#   %120 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%119, %37), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/Conv2d[conv2]
#   %121 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%120, %38, %39, %40, %41), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/BatchNorm2d[bn2]
#   %122 : Float(1, 64, 24, 24) = onnx::Add(%121, %116), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]
#   %123 : Float(1, 64, 24, 24) = onnx::Relu(%122), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/ReLU[relu]
#   %124 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%123, %43), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Conv2d[conv1]
#   %125 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%124, %44, %45, %46, %47), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/BatchNorm2d[bn1]
#   %126 : Float(1, 128, 12, 12) = onnx::Relu(%125), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/ReLU[relu]
#   %127 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%126, %49), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Conv2d[conv2]
#   %128 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%127, %50, %51, %52, %53), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/BatchNorm2d[bn2]
#   %129 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%123, %55), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]
#   %130 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%129, %56, %57, %58, %59), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]
#   %131 : Float(1, 128, 12, 12) = onnx::Add(%128, %130), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]
#   %132 : Float(1, 128, 12, 12) = onnx::Relu(%131), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/ReLU[relu]
#   %133 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%132, %61), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/Conv2d[conv1]
#   %134 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%133, %62, %63, %64, %65), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/BatchNorm2d[bn1]
#   %135 : Float(1, 128, 12, 12) = onnx::Relu(%134), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/ReLU[relu]
#   %136 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%135, %67), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/Conv2d[conv2]
#   %137 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%136, %68, %69, %70, %71), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/BatchNorm2d[bn2]
#   %138 : Float(1, 128, 12, 12) = onnx::Add(%137, %132), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]
#   %139 : Float(1, 128, 12, 12) = onnx::Relu(%138), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/ReLU[relu]
#   %140 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%139, %73), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/Conv2d[conv1]
#   %141 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%140, %74, %75, %76, %77), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/BatchNorm2d[bn1]
#   %142 : Float(1, 128, 12, 12) = onnx::Relu(%141), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/ReLU[relu]
#   %143 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%142, %79), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/Conv2d[conv2]
#   %144 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%143, %80, %81, %82, %83), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/BatchNorm2d[bn2]
#   %145 : Float(1, 128, 12, 12) = onnx::Add(%144, %139), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]
#   %146 : Float(1, 128, 12, 12) = onnx::Relu(%145), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/ReLU[relu]
#   %147 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%146, %85), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/Conv2d[conv1]
#   %148 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%147, %86, %87, %88, %89), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/BatchNorm2d[bn1]
#   %149 : Float(1, 128, 12, 12) = onnx::Relu(%148), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/ReLU[relu]
#   %150 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%149, %91), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/Conv2d[conv2]
#   %151 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%150, %92, %93, %94, %95), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/BatchNorm2d[bn2]
#   %152 : Float(1, 128, 12, 12) = onnx::Add(%151, %146), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]
#   %153 : Float(1, 128, 12, 12) = onnx::Relu(%152), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/ReLU[relu]
#   %154 : Dynamic = onnx::Pad[mode=constant, pads=[0, 0, 2, 2, 0, 0, 2, 2], value=0](%153), scope: CustomResnet/ResHead[reshead]/AvgPool2d[av_pool]
#   %155 : Float(1, 128, 2, 2) = onnx::AveragePool[kernel_shape=[8, 8], pads=[0, 0, 0, 0], strides=[6, 6]](%154), scope: CustomResnet/ResHead[reshead]/AvgPool2d[av_pool]
#   %156 : Dynamic = onnx::Constant[value=  -1  512 [ CPULongTensor{2} ]](), scope: CustomResnet/ResHead[reshead]
#   %157 : Float(1, 512) = onnx::Reshape(%155, %156), scope: CustomResnet/ResHead[reshead]
#   %158 : Float(1, 51) = onnx::Gemm[alpha=1, beta=1, broadcast=1, transB=1](%157, %97, %98), scope: CustomResnet/ResHead[reshead]/Linear[linear]
#   %159 : Dynamic = onnx::Constant[value= -1  51 [ CPULongTensor{2} ]](), scope: CustomResnet
#   %output1 : Float(1, 51) = onnx::Reshape(%158, %159), scope: CustomResnet
#   return (%output1);
# }

# %% [markdown]
# # Training Round Three (Test )

# %%
lr = 1e-3  
lr_array = np.array([lr/5,lr/3,lr])

for i in range(1,7):
    print (f'Run #{i}')
    epoch_count = i
    lr_list = train.set_lr_sched(epoch_count,mtrain.__len__()//batch_size,2.0)
    helper.lr_preview(lr_list)
    freeze = (i-1)*2
    if i == 4:
        freeze = 100
    train.one_run(train_dict,freeze,lr_list,lr_array)
# Out:
# Run #1
# Layer 0 : Grad:False
# Layer 1 : Grad:False
# Layer 2 : Grad:False
# Layer 3 : Grad:False
# Layer 4 : Grad:False
# Layer 5 : Grad:False
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f1d7ecb0c18>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 58, in detach
#     return reduction.recv_handle(conn)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/reduction.py", line 182, in recv_handle
#     return recvfds(s, 1)[0]
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/reduction.py", line 153, in recvfds
#     msg, ancdata, flags, addr = sock.recvmsg(1, socket.CMSG_LEN(bytes_size))
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.02832406386733055   train point_loss: 0.023662200197577477
# test mse_loss: 0.025691252201795578   test point_loss: 0.02204800210893154
# Done
# Run #2
# Layer 0 : Grad:False
# Layer 1 : Grad:False
# Layer 2 : Grad:False
# Layer 3 : Grad:False
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f1d80e783c8>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.0253114216029644   train point_loss: 0.02154204435646534
# test mse_loss: 0.022373326122760773   test point_loss: 0.017912881448864937
# Done
# Run #3
# Layer 0 : Grad:False
# Layer 1 : Grad:False
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.02534383535385132   train point_loss: 0.02110304683446884
# test mse_loss: 0.022163107991218567   test point_loss: 0.018849516287446022
# Done
# Run #4
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.025509461760520935   train point_loss: 0.02138279192149639
# test mse_loss: 0.027621014043688774   test point_loss: 0.023411884903907776
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f1d93944748>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
# train mse_loss: 0.024859953671693802   train point_loss: 0.020838739350438118
# test mse_loss: 0.023026153445243835   test point_loss: 0.018240241333842278
# Done
# Run #5
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.0252017080783844   train point_loss: 0.021217847242951393
# test mse_loss: 0.02778768166899681   test point_loss: 0.026976529508829117
# train mse_loss: 0.024697864428162575   train point_loss: 0.02078356221318245
# test mse_loss: 0.026074284687638283   test point_loss: 0.021861208602786064
# train mse_loss: 0.02558610774576664   train point_loss: 0.021857699379324913
# test mse_loss: 0.023095425218343735   test point_loss: 0.01980411447584629
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f1d7ed6bef0>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
# train mse_loss: 0.022590799257159233   train point_loss: 0.018762096762657166
# test mse_loss: 0.02131759561598301   test point_loss: 0.017080586403608322
# Done
# Run #6
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.02442711964249611   train point_loss: 0.020776262506842613
# test mse_loss: 0.02646154724061489   test point_loss: 0.022944224998354912
# train mse_loss: 0.024087779223918915   train point_loss: 0.020431919023394585
# test mse_loss: 0.02710924856364727   test point_loss: 0.02277476154267788
# train mse_loss: 0.024942010641098022   train point_loss: 0.021454039961099625
# test mse_loss: 0.022728634998202324   test point_loss: 0.019941166043281555
# train mse_loss: 0.02264314703643322   train point_loss: 0.01897205226123333
# test mse_loss: 0.02516883611679077   test point_loss: 0.021979764103889465

# %%
helper.view_predictions(res_net,train_data)
helper.export_onnx(res_net,'output/run_3')

# %% [markdown]
# # Training Round Four (Test )

# %%
lr = 1e-4  
lr_array = np.array([lr/5,lr/3,lr])

for i in range(1,7):
    print (f'Run #{i}')
    epoch_count = i
    lr_list = train.set_lr_sched(epoch_count,mtrain.__len__()//batch_size,2.0)
    helper.lr_preview(lr_list)

    freeze = 100
    train.one_run(train_dict,freeze,lr_list,lr_array)
# Out:
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f1d93aed208>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 58, in detach
#     return reduction.recv_handle(conn)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/reduction.py", line 182, in recv_handle
#     return recvfds(s, 1)[0]
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/reduction.py", line 153, in recvfds
#     msg, ancdata, flags, addr = sock.recvmsg(1, socket.CMSG_LEN(bytes_size))
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.020789464935660362   train point_loss: 0.017284883186221123
# test mse_loss: 0.020079948008060455   test point_loss: 0.016608010977506638
# Done
# Run #3
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.020682526752352715   train point_loss: 0.017123667523264885
# test mse_loss: 0.01971331238746643   test point_loss: 0.01668248325586319
# Done
# Run #4
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.020544057711958885   train point_loss: 0.01713874563574791
# test mse_loss: 0.0198857132345438   test point_loss: 0.016568444669246674
# train mse_loss: 0.02032318152487278   train point_loss: 0.016906430944800377
# test mse_loss: 0.01948012411594391   test point_loss: 0.016627037897706032
# Done
# Run #5
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.02008173242211342   train point_loss: 0.01680336892604828
# test mse_loss: 0.019414106383919716   test point_loss: 0.016799073666334152
# train mse_loss: 0.020147820934653282   train point_loss: 0.0168034415692091
# test mse_loss: 0.019952276721596718   test point_loss: 0.017543353140354156
# train mse_loss: 0.019982464611530304   train point_loss: 0.016673777252435684
# test mse_loss: 0.01905142329633236   test point_loss: 0.016048429533839226
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f1d94287a90>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 58, in detach
#     return reduction.recv_handle(conn)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/reduction.py", line 182, in recv_handle
#     return recvfds(s, 1)[0]
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/reduction.py", line 153, in recvfds
#     msg, ancdata, flags, addr = sock.recvmsg(1, socket.CMSG_LEN(bytes_size))
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.019854199141263962   train point_loss: 0.016507692635059357
# test mse_loss: 0.018894147127866745   test point_loss: 0.015973100438714027
# Done
# Run #6
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.019766390323638916   train point_loss: 0.01653706096112728
# test mse_loss: 0.018589042127132416   test point_loss: 0.016017548739910126
# train mse_loss: 0.019847629591822624   train point_loss: 0.01659567281603813
# test mse_loss: 0.018881957978010178   test point_loss: 0.015912123024463654
# train mse_loss: 0.019713494926691055   train point_loss: 0.01654105819761753
# test mse_loss: 0.019052516669034958   test point_loss: 0.016260702162981033
# train mse_loss: 0.019379565492272377   train point_loss: 0.016189109534025192
# test mse_loss: 0.019827628508210182   test point_loss: 0.017410043627023697
# train mse_loss: 0.019662270322442055   train point_loss: 0.016565857455134392
# test mse_loss: 0.01869012787938118   test point_loss: 0.015742970630526543
# train mse_loss: 0.019552508369088173   train point_loss: 0.016420040279626846
# test mse_loss: 0.01928083971142769   test point_loss: 0.015835244208574295
# train mse_loss: 0.019210124388337135   train point_loss: 0.016110457479953766
# test mse_loss: 0.018967168405652046   test point_loss: 0.015912801027297974
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7f1d93cfa710>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.018886756151914597   train point_loss: 0.01587681658565998
# test mse_loss: 0.018260937184095383   test point_loss: 0.015468659810721874
# Done

# %%
helper.view_predictions(res_net,train_data)
helper.export_onnx(res_net,'output/run_4')
# Out:
# graph(%0 : Float(1, 3, 96, 96)
#       %1 : Float(64, 3, 7, 7)
#       %2 : Float(64)
#       %3 : Float(64)
#       %4 : Float(64)
#       %5 : Float(64)
#       %6 : Long()
#       %7 : Float(64, 64, 3, 3)
#       %8 : Float(64)
#       %9 : Float(64)
#       %10 : Float(64)
#       %11 : Float(64)
#       %12 : Long()
#       %13 : Float(64, 64, 3, 3)
#       %14 : Float(64)
#       %15 : Float(64)
#       %16 : Float(64)
#       %17 : Float(64)
#       %18 : Long()
#       %19 : Float(64, 64, 3, 3)
#       %20 : Float(64)
#       %21 : Float(64)
#       %22 : Float(64)
#       %23 : Float(64)
#       %24 : Long()
#       %25 : Float(64, 64, 3, 3)
#       %26 : Float(64)
#       %27 : Float(64)
#       %28 : Float(64)
#       %29 : Float(64)
#       %30 : Long()
#       %31 : Float(64, 64, 3, 3)
#       %32 : Float(64)
#       %33 : Float(64)
#       %34 : Float(64)
#       %35 : Float(64)
#       %36 : Long()
#       %37 : Float(64, 64, 3, 3)
#       %38 : Float(64)
#       %39 : Float(64)
#       %40 : Float(64)
#       %41 : Float(64)
#       %42 : Long()
#       %43 : Float(128, 64, 3, 3)
#       %44 : Float(128)
#       %45 : Float(128)
#       %46 : Float(128)
#       %47 : Float(128)
#       %48 : Long()
#       %49 : Float(128, 128, 3, 3)
#       %50 : Float(128)
#       %51 : Float(128)
#       %52 : Float(128)
#       %53 : Float(128)
#       %54 : Long()
#       %55 : Float(128, 64, 1, 1)
#       %56 : Float(128)
#       %57 : Float(128)
#       %58 : Float(128)
#       %59 : Float(128)
#       %60 : Long()
#       %61 : Float(128, 128, 3, 3)
#       %62 : Float(128)
#       %63 : Float(128)
#       %64 : Float(128)
#       %65 : Float(128)
#       %66 : Long()
#       %67 : Float(128, 128, 3, 3)
#       %68 : Float(128)
#       %69 : Float(128)
#       %70 : Float(128)
#       %71 : Float(128)
#       %72 : Long()
#       %73 : Float(128, 128, 3, 3)
#       %74 : Float(128)
#       %75 : Float(128)
#       %76 : Float(128)
#       %77 : Float(128)
#       %78 : Long()
#       %79 : Float(128, 128, 3, 3)
#       %80 : Float(128)
#       %81 : Float(128)
#       %82 : Float(128)
#       %83 : Float(128)
#       %84 : Long()
#       %85 : Float(128, 128, 3, 3)
#       %86 : Float(128)
#       %87 : Float(128)
#       %88 : Float(128)
#       %89 : Float(128)
#       %90 : Long()
#       %91 : Float(128, 128, 3, 3)
#       %92 : Float(128)
#       %93 : Float(128)
#       %94 : Float(128)
#       %95 : Float(128)
#       %96 : Long()
#       %97 : Float(51, 512)
#       %98 : Float(51)) {
#   %99 : Float(1, 64, 48, 48) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[2, 2]](%0, %1), scope: CustomResnet/Sequential[resnet]/Conv2d[0]
#   %100 : Float(1, 64, 48, 48) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%99, %2, %3, %4, %5), scope: CustomResnet/Sequential[resnet]/BatchNorm2d[1]
#   %101 : Float(1, 64, 48, 48) = onnx::Relu(%100), scope: CustomResnet/Sequential[resnet]/ReLU[2]
#   %102 : Float(1, 64, 24, 24) = onnx::MaxPool[kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%101), scope: CustomResnet/Sequential[resnet]/MaxPool2d[3]
#   %103 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%102, %7), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/Conv2d[conv1]
#   %104 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%103, %8, %9, %10, %11), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/BatchNorm2d[bn1]
#   %105 : Float(1, 64, 24, 24) = onnx::Relu(%104), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/ReLU[relu]
#   %106 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%105, %13), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/Conv2d[conv2]
#   %107 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%106, %14, %15, %16, %17), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/BatchNorm2d[bn2]
#   %108 : Float(1, 64, 24, 24) = onnx::Add(%107, %102), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]
#   %109 : Float(1, 64, 24, 24) = onnx::Relu(%108), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/ReLU[relu]
#   %110 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%109, %19), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/Conv2d[conv1]
#   %111 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%110, %20, %21, %22, %23), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/BatchNorm2d[bn1]
#   %112 : Float(1, 64, 24, 24) = onnx::Relu(%111), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/ReLU[relu]
#   %113 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%112, %25), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/Conv2d[conv2]
#   %114 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%113, %26, %27, %28, %29), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/BatchNorm2d[bn2]
#   %115 : Float(1, 64, 24, 24) = onnx::Add(%114, %109), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]
#   %116 : Float(1, 64, 24, 24) = onnx::Relu(%115), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/ReLU[relu]
#   %117 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%116, %31), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/Conv2d[conv1]
#   %118 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%117, %32, %33, %34, %35), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/BatchNorm2d[bn1]
#   %119 : Float(1, 64, 24, 24) = onnx::Relu(%118), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/ReLU[relu]
#   %120 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%119, %37), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/Conv2d[conv2]
#   %121 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%120, %38, %39, %40, %41), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/BatchNorm2d[bn2]
#   %122 : Float(1, 64, 24, 24) = onnx::Add(%121, %116), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]
#   %123 : Float(1, 64, 24, 24) = onnx::Relu(%122), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/ReLU[relu]
#   %124 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%123, %43), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Conv2d[conv1]
#   %125 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%124, %44, %45, %46, %47), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/BatchNorm2d[bn1]
#   %126 : Float(1, 128, 12, 12) = onnx::Relu(%125), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/ReLU[relu]
#   %127 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%126, %49), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Conv2d[conv2]
#   %128 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%127, %50, %51, %52, %53), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/BatchNorm2d[bn2]
#   %129 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%123, %55), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]
#   %130 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%129, %56, %57, %58, %59), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]
#   %131 : Float(1, 128, 12, 12) = onnx::Add(%128, %130), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]
#   %132 : Float(1, 128, 12, 12) = onnx::Relu(%131), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/ReLU[relu]
#   %133 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%132, %61), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/Conv2d[conv1]
#   %134 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%133, %62, %63, %64, %65), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/BatchNorm2d[bn1]
#   %135 : Float(1, 128, 12, 12) = onnx::Relu(%134), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/ReLU[relu]
#   %136 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%135, %67), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/Conv2d[conv2]
#   %137 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%136, %68, %69, %70, %71), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/BatchNorm2d[bn2]
#   %138 : Float(1, 128, 12, 12) = onnx::Add(%137, %132), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]
#   %139 : Float(1, 128, 12, 12) = onnx::Relu(%138), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/ReLU[relu]
#   %140 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%139, %73), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/Conv2d[conv1]
#   %141 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%140, %74, %75, %76, %77), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/BatchNorm2d[bn1]
#   %142 : Float(1, 128, 12, 12) = onnx::Relu(%141), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/ReLU[relu]
#   %143 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%142, %79), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/Conv2d[conv2]
#   %144 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%143, %80, %81, %82, %83), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/BatchNorm2d[bn2]
#   %145 : Float(1, 128, 12, 12) = onnx::Add(%144, %139), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]
#   %146 : Float(1, 128, 12, 12) = onnx::Relu(%145), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/ReLU[relu]
#   %147 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%146, %85), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/Conv2d[conv1]
#   %148 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%147, %86, %87, %88, %89), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/BatchNorm2d[bn1]
#   %149 : Float(1, 128, 12, 12) = onnx::Relu(%148), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/ReLU[relu]
#   %150 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%149, %91), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/Conv2d[conv2]
#   %151 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%150, %92, %93, %94, %95), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/BatchNorm2d[bn2]
#   %152 : Float(1, 128, 12, 12) = onnx::Add(%151, %146), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]
#   %153 : Float(1, 128, 12, 12) = onnx::Relu(%152), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/ReLU[relu]
#   %154 : Dynamic = onnx::Pad[mode=constant, pads=[0, 0, 2, 2, 0, 0, 2, 2], value=0](%153), scope: CustomResnet/ResHead[reshead]/AvgPool2d[av_pool]
#   %155 : Float(1, 128, 2, 2) = onnx::AveragePool[kernel_shape=[8, 8], pads=[0, 0, 0, 0], strides=[6, 6]](%154), scope: CustomResnet/ResHead[reshead]/AvgPool2d[av_pool]
#   %156 : Dynamic = onnx::Constant[value=  -1  512 [ CPULongTensor{2} ]](), scope: CustomResnet/ResHead[reshead]
#   %157 : Float(1, 512) = onnx::Reshape(%155, %156), scope: CustomResnet/ResHead[reshead]
#   %158 : Float(1, 51) = onnx::Gemm[alpha=1, beta=1, broadcast=1, transB=1](%157, %97, %98), scope: CustomResnet/ResHead[reshead]/Linear[linear]
#   %159 : Dynamic = onnx::Constant[value= -1  51 [ CPULongTensor{2} ]](), scope: CustomResnet
#   %output1 : Float(1, 51) = onnx::Reshape(%158, %159), scope: CustomResnet
#   return (%output1);
# }
