# %% [markdown]
# # Imports

# %%
import math
import time
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as opt

import onnx
from onnx import optimizer

from util import losses as loss
from util import loaders as load
from util import training as train
from util import helpers as helper
from models import networks as n

# %% [markdown]
# # Setup Network, Data Generator, Optimizer, Losses

# %%
############################################################################
# Network
############################################################################

res_net = n.CustomResnet(51)
res_net.cuda()

############################################################################
# Loss
############################################################################

mse_crit = nn.MSELoss()
point_crit = loss.PointLoss().cuda()

############################################################################
# Optimizer
############################################################################

lr = 1e-3
lr_array = np.array([lr/100,lr/10,lr])
lr_groups = res_net.lr_groups()
opt_params = [{"params":lr_groups[0].parameters(),"lr":lr_array[0]},
              {"params":lr_groups[1].parameters(),"lr":lr_array[1]},
              {"params":lr_groups[2].parameters(),"lr":lr_array[2]}]

adam_opt = opt.Adam(opt_params,betas=(0.9, 0.999),weight_decay= .0001)

############################################################################
# Data Generators
############################################################################

transform = load.NormDenorm([.5, .5, .5], [.5, .5, .5])
train_data= load.LandMarkGenerator( transform, output_res=96, size = 10000, rand_rot = .7)
test_data = load.LandMarkGenerator( transform, output_res=96, size = 300, rand_rot = .7)   
batch_size = 8
mtrain = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=8, shuffle=True, drop_last=True)
mtest  = torch.utils.data.DataLoader(test_data, batch_size=batch_size, num_workers=8, shuffle=False, drop_last=True)

############################################################################
# Train Dictionary
############################################################################

train_dict = {
    "train_loader":mtrain,
    "test_loader":mtest,
    "opt":adam_opt,
    "net":res_net,
    "mse_crit":mse_crit,
    "point_crit":point_crit
}

output_name = "mse_only"

# %% [markdown]
# # Example Training Data

# %%
% matplotlib inline
helper.view_dataset(train_data,transform)

# %% [markdown]
# # Training Round One

# %%
lr = 1e-3  
lr_array = np.array([lr/5,lr/3,lr])

for i in range(1,7):
    print (f'Run #{i}')
    epoch_count = i
    lr_list = train.set_lr_sched(epoch_count,mtrain.__len__()//batch_size,2.0)
    helper.lr_preview(lr_list)
    freeze = (i-1)*2
    if i == 4:
        freeze = 100
    train.one_run(train_dict,freeze,lr_list,lr_array)
# Out:
# Run #1
# Layer 0 : Grad:False
# Layer 1 : Grad:False
# Layer 2 : Grad:False
# Layer 3 : Grad:False
# Layer 4 : Grad:False
# Layer 5 : Grad:False
# train mse_loss: 0.05094066262245178   train point_loss: 0.04844949021935463
# test mse_loss: 0.049308523535728455   test point_loss: 0.04716247692704201
# Done
# Run #2
# Layer 0 : Grad:False
# Layer 1 : Grad:False
# Layer 2 : Grad:False
# Layer 3 : Grad:False
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fa1932a5cf8>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
# train mse_loss: 0.04799971729516983   train point_loss: 0.04375438019633293
# test mse_loss: 0.044457875192165375   test point_loss: 0.03849994018673897
# Done
# Run #3
# Layer 0 : Grad:False
# Layer 1 : Grad:False
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fa1932bf390>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.04115040972828865   train point_loss: 0.03529984876513481
# test mse_loss: 0.03698554262518883   test point_loss: 0.03012862801551819
# Done
# Run #4
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.03582745045423508   train point_loss: 0.03039245307445526
# test mse_loss: 0.041181620210409164   test point_loss: 0.03310370817780495
# train mse_loss: 0.03246653079986572   train point_loss: 0.027724992483854294
# test mse_loss: 0.030068330466747284   test point_loss: 0.024190718308091164
# Done
# Run #5
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.03181573003530502   train point_loss: 0.02746177278459072
# test mse_loss: 0.0343562476336956   test point_loss: 0.029873449355363846
# train mse_loss: 0.02999461069703102   train point_loss: 0.02624789997935295
# test mse_loss: 0.03453575447201729   test point_loss: 0.035713255405426025
# train mse_loss: 0.03012145310640335   train point_loss: 0.026553882285952568
# test mse_loss: 0.02664065733551979   test point_loss: 0.025086745619773865
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fa19222acf8>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
# train mse_loss: 0.025817157700657845   train point_loss: 0.02309231646358967
# test mse_loss: 0.024288667365908623   test point_loss: 0.02181483991444111
# Done
# Run #6
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.028307024389505386   train point_loss: 0.02531931735575199
# test mse_loss: 0.02962687611579895   test point_loss: 0.02729622647166252
# train mse_loss: 0.027138037607073784   train point_loss: 0.024465413764119148
# test mse_loss: 0.03154971823096275   test point_loss: 0.029710540547966957
# train mse_loss: 0.027931012213230133   train point_loss: 0.02513938397169113
# test mse_loss: 0.026626190170645714   test point_loss: 0.023516349494457245
# train mse_loss: 0.024754589423537254   train point_loss: 0.022610876709222794
# test mse_loss: 0.03089834190905094   test point_loss: 0.029271867126226425
# train mse_loss: 0.028110571205615997   train point_loss: 0.025551874190568924
# test mse_loss: 0.02724812552332878   test point_loss: 0.023901397362351418
# train mse_loss: 0.026360364630818367   train point_loss: 0.02409948781132698
# test mse_loss: 0.024787431582808495   test point_loss: 0.023192452266812325
# train mse_loss: 0.023424573242664337   train point_loss: 0.021761944517493248
# test mse_loss: 0.022219888865947723   test point_loss: 0.02042536810040474
# train mse_loss: 0.02183598466217518   train point_loss: 0.020479612052440643
# test mse_loss: 0.020702600479125977   test point_loss: 0.019455090165138245
# Done

# %%
helper.view_predictions(res_net,train_data)
helper.export_onnx(res_net,'output/'+output_name+'run_1')
# Out:
# graph(%0 : Float(1, 3, 96, 96)
#       %1 : Float(64, 3, 7, 7)
#       %2 : Float(64)
#       %3 : Float(64)
#       %4 : Float(64)
#       %5 : Float(64)
#       %6 : Long()
#       %7 : Float(64, 64, 3, 3)
#       %8 : Float(64)
#       %9 : Float(64)
#       %10 : Float(64)
#       %11 : Float(64)
#       %12 : Long()
#       %13 : Float(64, 64, 3, 3)
#       %14 : Float(64)
#       %15 : Float(64)
#       %16 : Float(64)
#       %17 : Float(64)
#       %18 : Long()
#       %19 : Float(64, 64, 3, 3)
#       %20 : Float(64)
#       %21 : Float(64)
#       %22 : Float(64)
#       %23 : Float(64)
#       %24 : Long()
#       %25 : Float(64, 64, 3, 3)
#       %26 : Float(64)
#       %27 : Float(64)
#       %28 : Float(64)
#       %29 : Float(64)
#       %30 : Long()
#       %31 : Float(64, 64, 3, 3)
#       %32 : Float(64)
#       %33 : Float(64)
#       %34 : Float(64)
#       %35 : Float(64)
#       %36 : Long()
#       %37 : Float(64, 64, 3, 3)
#       %38 : Float(64)
#       %39 : Float(64)
#       %40 : Float(64)
#       %41 : Float(64)
#       %42 : Long()
#       %43 : Float(128, 64, 3, 3)
#       %44 : Float(128)
#       %45 : Float(128)
#       %46 : Float(128)
#       %47 : Float(128)
#       %48 : Long()
#       %49 : Float(128, 128, 3, 3)
#       %50 : Float(128)
#       %51 : Float(128)
#       %52 : Float(128)
#       %53 : Float(128)
#       %54 : Long()
#       %55 : Float(128, 64, 1, 1)
#       %56 : Float(128)
#       %57 : Float(128)
#       %58 : Float(128)
#       %59 : Float(128)
#       %60 : Long()
#       %61 : Float(128, 128, 3, 3)
#       %62 : Float(128)
#       %63 : Float(128)
#       %64 : Float(128)
#       %65 : Float(128)
#       %66 : Long()
#       %67 : Float(128, 128, 3, 3)
#       %68 : Float(128)
#       %69 : Float(128)
#       %70 : Float(128)
#       %71 : Float(128)
#       %72 : Long()
#       %73 : Float(128, 128, 3, 3)
#       %74 : Float(128)
#       %75 : Float(128)
#       %76 : Float(128)
#       %77 : Float(128)
#       %78 : Long()
#       %79 : Float(128, 128, 3, 3)
#       %80 : Float(128)
#       %81 : Float(128)
#       %82 : Float(128)
#       %83 : Float(128)
#       %84 : Long()
#       %85 : Float(128, 128, 3, 3)
#       %86 : Float(128)
#       %87 : Float(128)
#       %88 : Float(128)
#       %89 : Float(128)
#       %90 : Long()
#       %91 : Float(128, 128, 3, 3)
#       %92 : Float(128)
#       %93 : Float(128)
#       %94 : Float(128)
#       %95 : Float(128)
#       %96 : Long()
#       %97 : Float(51, 512)
#       %98 : Float(51)) {
#   %99 : Float(1, 64, 48, 48) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[2, 2]](%0, %1), scope: CustomResnet/Sequential[resnet]/Conv2d[0]
#   %100 : Float(1, 64, 48, 48) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%99, %2, %3, %4, %5), scope: CustomResnet/Sequential[resnet]/BatchNorm2d[1]
#   %101 : Float(1, 64, 48, 48) = onnx::Relu(%100), scope: CustomResnet/Sequential[resnet]/ReLU[2]
#   %102 : Float(1, 64, 24, 24) = onnx::MaxPool[kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%101), scope: CustomResnet/Sequential[resnet]/MaxPool2d[3]
#   %103 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%102, %7), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/Conv2d[conv1]
#   %104 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%103, %8, %9, %10, %11), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/BatchNorm2d[bn1]
#   %105 : Float(1, 64, 24, 24) = onnx::Relu(%104), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/ReLU[relu]
#   %106 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%105, %13), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/Conv2d[conv2]
#   %107 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%106, %14, %15, %16, %17), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/BatchNorm2d[bn2]
#   %108 : Float(1, 64, 24, 24) = onnx::Add(%107, %102), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]
#   %109 : Float(1, 64, 24, 24) = onnx::Relu(%108), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/ReLU[relu]
#   %110 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%109, %19), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/Conv2d[conv1]
#   %111 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%110, %20, %21, %22, %23), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/BatchNorm2d[bn1]
#   %112 : Float(1, 64, 24, 24) = onnx::Relu(%111), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/ReLU[relu]
#   %113 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%112, %25), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/Conv2d[conv2]
#   %114 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%113, %26, %27, %28, %29), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/BatchNorm2d[bn2]
#   %115 : Float(1, 64, 24, 24) = onnx::Add(%114, %109), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]
#   %116 : Float(1, 64, 24, 24) = onnx::Relu(%115), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/ReLU[relu]
#   %117 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%116, %31), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/Conv2d[conv1]
#   %118 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%117, %32, %33, %34, %35), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/BatchNorm2d[bn1]
#   %119 : Float(1, 64, 24, 24) = onnx::Relu(%118), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/ReLU[relu]
#   %120 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%119, %37), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/Conv2d[conv2]
#   %121 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%120, %38, %39, %40, %41), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/BatchNorm2d[bn2]
#   %122 : Float(1, 64, 24, 24) = onnx::Add(%121, %116), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]
#   %123 : Float(1, 64, 24, 24) = onnx::Relu(%122), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/ReLU[relu]
#   %124 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%123, %43), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Conv2d[conv1]
#   %125 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%124, %44, %45, %46, %47), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/BatchNorm2d[bn1]
#   %126 : Float(1, 128, 12, 12) = onnx::Relu(%125), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/ReLU[relu]
#   %127 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%126, %49), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Conv2d[conv2]
#   %128 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%127, %50, %51, %52, %53), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/BatchNorm2d[bn2]
#   %129 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%123, %55), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]
#   %130 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%129, %56, %57, %58, %59), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]
#   %131 : Float(1, 128, 12, 12) = onnx::Add(%128, %130), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]
#   %132 : Float(1, 128, 12, 12) = onnx::Relu(%131), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/ReLU[relu]
#   %133 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%132, %61), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/Conv2d[conv1]
#   %134 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%133, %62, %63, %64, %65), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/BatchNorm2d[bn1]
#   %135 : Float(1, 128, 12, 12) = onnx::Relu(%134), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/ReLU[relu]
#   %136 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%135, %67), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/Conv2d[conv2]
#   %137 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%136, %68, %69, %70, %71), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/BatchNorm2d[bn2]
#   %138 : Float(1, 128, 12, 12) = onnx::Add(%137, %132), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]
#   %139 : Float(1, 128, 12, 12) = onnx::Relu(%138), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/ReLU[relu]
#   %140 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%139, %73), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/Conv2d[conv1]
#   %141 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%140, %74, %75, %76, %77), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/BatchNorm2d[bn1]
#   %142 : Float(1, 128, 12, 12) = onnx::Relu(%141), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/ReLU[relu]
#   %143 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%142, %79), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/Conv2d[conv2]
#   %144 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%143, %80, %81, %82, %83), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/BatchNorm2d[bn2]
#   %145 : Float(1, 128, 12, 12) = onnx::Add(%144, %139), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]
#   %146 : Float(1, 128, 12, 12) = onnx::Relu(%145), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/ReLU[relu]
#   %147 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%146, %85), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/Conv2d[conv1]
#   %148 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%147, %86, %87, %88, %89), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/BatchNorm2d[bn1]
#   %149 : Float(1, 128, 12, 12) = onnx::Relu(%148), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/ReLU[relu]
#   %150 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%149, %91), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/Conv2d[conv2]
#   %151 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%150, %92, %93, %94, %95), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/BatchNorm2d[bn2]
#   %152 : Float(1, 128, 12, 12) = onnx::Add(%151, %146), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]
#   %153 : Float(1, 128, 12, 12) = onnx::Relu(%152), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/ReLU[relu]
#   %154 : Dynamic = onnx::Pad[mode=constant, pads=[0, 0, 2, 2, 0, 0, 2, 2], value=0](%153), scope: CustomResnet/ResHead[reshead]/AvgPool2d[av_pool]
#   %155 : Float(1, 128, 2, 2) = onnx::AveragePool[kernel_shape=[8, 8], pads=[0, 0, 0, 0], strides=[6, 6]](%154), scope: CustomResnet/ResHead[reshead]/AvgPool2d[av_pool]
#   %156 : Dynamic = onnx::Constant[value=  -1  512 [ CPULongTensor{2} ]](), scope: CustomResnet/ResHead[reshead]
#   %157 : Float(1, 512) = onnx::Reshape(%155, %156), scope: CustomResnet/ResHead[reshead]
#   %158 : Float(1, 51) = onnx::Gemm[alpha=1, beta=1, broadcast=1, transB=1](%157, %97, %98), scope: CustomResnet/ResHead[reshead]/Linear[linear]
#   %159 : Dynamic = onnx::Constant[value= -1  51 [ CPULongTensor{2} ]](), scope: CustomResnet
#   %output1 : Float(1, 51) = onnx::Reshape(%158, %159), scope: CustomResnet
#   return (%output1);
# }

# %% [markdown]
# # Training Round Two

# %%
lr = 1e-4  
lr_array = np.array([lr/5,lr/3,lr])

for i in range(1,7):
    print (f'Run #{i}')
    epoch_count = i
    lr_list = train.set_lr_sched(epoch_count,mtrain.__len__()//batch_size,2.0)
    helper.lr_preview(lr_list)

    freeze = 100
    train.one_run(train_dict,freeze,lr_list,lr_array)
# Out:
# Run #1
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.021556606516242027   train point_loss: 0.020091308280825615
# test mse_loss: 0.02116895280778408   test point_loss: 0.020159561187028885
# Done
# Run #2
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fa1929e6630>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
# train mse_loss: 0.021992960944771767   train point_loss: 0.02059343084692955
# test mse_loss: 0.021217403933405876   test point_loss: 0.02028758078813553
# Done
# Run #3
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.021688366308808327   train point_loss: 0.020333437249064445
# test mse_loss: 0.02036713995039463   test point_loss: 0.019208626821637154
# Done
# Run #4
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.021261004731059074   train point_loss: 0.020392514765262604
# test mse_loss: 0.02072278968989849   test point_loss: 0.019368460401892662
# train mse_loss: 0.021205315366387367   train point_loss: 0.020138422027230263
# test mse_loss: 0.019770342856645584   test point_loss: 0.019237734377384186
# Done
# Run #5
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.021120553836226463   train point_loss: 0.019922982901334763
# test mse_loss: 0.02008471079170704   test point_loss: 0.01847570203244686
# train mse_loss: 0.020869601517915726   train point_loss: 0.019898157566785812
# test mse_loss: 0.020953139290213585   test point_loss: 0.01927078887820244
# train mse_loss: 0.020766543224453926   train point_loss: 0.01985660381615162
# test mse_loss: 0.020290667191147804   test point_loss: 0.018442634493112564
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fa17ebdd940>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.020234394818544388   train point_loss: 0.019505944103002548
# test mse_loss: 0.019795171916484833   test point_loss: 0.019147545099258423
# Done
# Run #6
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.020529715344309807   train point_loss: 0.019808556884527206
# test mse_loss: 0.018932370468974113   test point_loss: 0.019188961014151573
# train mse_loss: 0.020376885309815407   train point_loss: 0.019637761637568474
# test mse_loss: 0.019268855452537537   test point_loss: 0.019421059638261795
# train mse_loss: 0.020226160064339638   train point_loss: 0.019601022824645042
# test mse_loss: 0.018246471881866455   test point_loss: 0.01836107298731804
# train mse_loss: 0.01966383308172226   train point_loss: 0.019107703119516373
# test mse_loss: 0.019401907920837402   test point_loss: 0.01852288469672203
# train mse_loss: 0.02013198845088482   train point_loss: 0.019425736740231514
# test mse_loss: 0.019366834312677383   test point_loss: 0.018232906237244606
# train mse_loss: 0.019716458395123482   train point_loss: 0.01918513886630535
# test mse_loss: 0.017595957964658737   test point_loss: 0.017814990133047104
# train mse_loss: 0.01927991397678852   train point_loss: 0.018812818452715874
# test mse_loss: 0.01840105839073658   test point_loss: 0.017312508076429367
# train mse_loss: 0.019073771312832832   train point_loss: 0.018712101504206657
# test mse_loss: 0.01758047193288803   test point_loss: 0.01782175526022911
# Done

# %%
helper.view_predictions(res_net,train_data)
helper.export_onnx(res_net,'output/'+output_name+'run_2')
# Out:
# graph(%0 : Float(1, 3, 96, 96)
#       %1 : Float(64, 3, 7, 7)
#       %2 : Float(64)
#       %3 : Float(64)
#       %4 : Float(64)
#       %5 : Float(64)
#       %6 : Long()
#       %7 : Float(64, 64, 3, 3)
#       %8 : Float(64)
#       %9 : Float(64)
#       %10 : Float(64)
#       %11 : Float(64)
#       %12 : Long()
#       %13 : Float(64, 64, 3, 3)
#       %14 : Float(64)
#       %15 : Float(64)
#       %16 : Float(64)
#       %17 : Float(64)
#       %18 : Long()
#       %19 : Float(64, 64, 3, 3)
#       %20 : Float(64)
#       %21 : Float(64)
#       %22 : Float(64)
#       %23 : Float(64)
#       %24 : Long()
#       %25 : Float(64, 64, 3, 3)
#       %26 : Float(64)
#       %27 : Float(64)
#       %28 : Float(64)
#       %29 : Float(64)
#       %30 : Long()
#       %31 : Float(64, 64, 3, 3)
#       %32 : Float(64)
#       %33 : Float(64)
#       %34 : Float(64)
#       %35 : Float(64)
#       %36 : Long()
#       %37 : Float(64, 64, 3, 3)
#       %38 : Float(64)
#       %39 : Float(64)
#       %40 : Float(64)
#       %41 : Float(64)
#       %42 : Long()
#       %43 : Float(128, 64, 3, 3)
#       %44 : Float(128)
#       %45 : Float(128)
#       %46 : Float(128)
#       %47 : Float(128)
#       %48 : Long()
#       %49 : Float(128, 128, 3, 3)
#       %50 : Float(128)
#       %51 : Float(128)
#       %52 : Float(128)
#       %53 : Float(128)
#       %54 : Long()
#       %55 : Float(128, 64, 1, 1)
#       %56 : Float(128)
#       %57 : Float(128)
#       %58 : Float(128)
#       %59 : Float(128)
#       %60 : Long()
#       %61 : Float(128, 128, 3, 3)
#       %62 : Float(128)
#       %63 : Float(128)
#       %64 : Float(128)
#       %65 : Float(128)
#       %66 : Long()
#       %67 : Float(128, 128, 3, 3)
#       %68 : Float(128)
#       %69 : Float(128)
#       %70 : Float(128)
#       %71 : Float(128)
#       %72 : Long()
#       %73 : Float(128, 128, 3, 3)
#       %74 : Float(128)
#       %75 : Float(128)
#       %76 : Float(128)
#       %77 : Float(128)
#       %78 : Long()
#       %79 : Float(128, 128, 3, 3)
#       %80 : Float(128)
#       %81 : Float(128)
#       %82 : Float(128)
#       %83 : Float(128)
#       %84 : Long()
#       %85 : Float(128, 128, 3, 3)
#       %86 : Float(128)
#       %87 : Float(128)
#       %88 : Float(128)
#       %89 : Float(128)
#       %90 : Long()
#       %91 : Float(128, 128, 3, 3)
#       %92 : Float(128)
#       %93 : Float(128)
#       %94 : Float(128)
#       %95 : Float(128)
#       %96 : Long()
#       %97 : Float(51, 512)
#       %98 : Float(51)) {
#   %99 : Float(1, 64, 48, 48) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[2, 2]](%0, %1), scope: CustomResnet/Sequential[resnet]/Conv2d[0]
#   %100 : Float(1, 64, 48, 48) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%99, %2, %3, %4, %5), scope: CustomResnet/Sequential[resnet]/BatchNorm2d[1]
#   %101 : Float(1, 64, 48, 48) = onnx::Relu(%100), scope: CustomResnet/Sequential[resnet]/ReLU[2]
#   %102 : Float(1, 64, 24, 24) = onnx::MaxPool[kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%101), scope: CustomResnet/Sequential[resnet]/MaxPool2d[3]
#   %103 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%102, %7), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/Conv2d[conv1]
#   %104 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%103, %8, %9, %10, %11), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/BatchNorm2d[bn1]
#   %105 : Float(1, 64, 24, 24) = onnx::Relu(%104), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/ReLU[relu]
#   %106 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%105, %13), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/Conv2d[conv2]
#   %107 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%106, %14, %15, %16, %17), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/BatchNorm2d[bn2]
#   %108 : Float(1, 64, 24, 24) = onnx::Add(%107, %102), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]
#   %109 : Float(1, 64, 24, 24) = onnx::Relu(%108), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/ReLU[relu]
#   %110 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%109, %19), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/Conv2d[conv1]
#   %111 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%110, %20, %21, %22, %23), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/BatchNorm2d[bn1]
#   %112 : Float(1, 64, 24, 24) = onnx::Relu(%111), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/ReLU[relu]
#   %113 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%112, %25), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/Conv2d[conv2]
#   %114 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%113, %26, %27, %28, %29), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/BatchNorm2d[bn2]
#   %115 : Float(1, 64, 24, 24) = onnx::Add(%114, %109), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]
#   %116 : Float(1, 64, 24, 24) = onnx::Relu(%115), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/ReLU[relu]
#   %117 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%116, %31), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/Conv2d[conv1]
#   %118 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%117, %32, %33, %34, %35), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/BatchNorm2d[bn1]
#   %119 : Float(1, 64, 24, 24) = onnx::Relu(%118), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/ReLU[relu]
#   %120 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%119, %37), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/Conv2d[conv2]
#   %121 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%120, %38, %39, %40, %41), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/BatchNorm2d[bn2]
#   %122 : Float(1, 64, 24, 24) = onnx::Add(%121, %116), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]
#   %123 : Float(1, 64, 24, 24) = onnx::Relu(%122), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/ReLU[relu]
#   %124 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%123, %43), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Conv2d[conv1]
#   %125 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%124, %44, %45, %46, %47), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/BatchNorm2d[bn1]
#   %126 : Float(1, 128, 12, 12) = onnx::Relu(%125), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/ReLU[relu]
#   %127 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%126, %49), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Conv2d[conv2]
#   %128 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%127, %50, %51, %52, %53), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/BatchNorm2d[bn2]
#   %129 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%123, %55), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]
#   %130 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%129, %56, %57, %58, %59), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]
#   %131 : Float(1, 128, 12, 12) = onnx::Add(%128, %130), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]
#   %132 : Float(1, 128, 12, 12) = onnx::Relu(%131), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/ReLU[relu]
#   %133 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%132, %61), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/Conv2d[conv1]
#   %134 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%133, %62, %63, %64, %65), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/BatchNorm2d[bn1]
#   %135 : Float(1, 128, 12, 12) = onnx::Relu(%134), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/ReLU[relu]
#   %136 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%135, %67), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/Conv2d[conv2]
#   %137 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%136, %68, %69, %70, %71), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/BatchNorm2d[bn2]
#   %138 : Float(1, 128, 12, 12) = onnx::Add(%137, %132), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]
#   %139 : Float(1, 128, 12, 12) = onnx::Relu(%138), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/ReLU[relu]
#   %140 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%139, %73), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/Conv2d[conv1]
#   %141 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%140, %74, %75, %76, %77), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/BatchNorm2d[bn1]
#   %142 : Float(1, 128, 12, 12) = onnx::Relu(%141), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/ReLU[relu]
#   %143 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%142, %79), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/Conv2d[conv2]
#   %144 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%143, %80, %81, %82, %83), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/BatchNorm2d[bn2]
#   %145 : Float(1, 128, 12, 12) = onnx::Add(%144, %139), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]
#   %146 : Float(1, 128, 12, 12) = onnx::Relu(%145), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/ReLU[relu]
#   %147 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%146, %85), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/Conv2d[conv1]
#   %148 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%147, %86, %87, %88, %89), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/BatchNorm2d[bn1]
#   %149 : Float(1, 128, 12, 12) = onnx::Relu(%148), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/ReLU[relu]
#   %150 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%149, %91), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/Conv2d[conv2]
#   %151 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%150, %92, %93, %94, %95), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/BatchNorm2d[bn2]
#   %152 : Float(1, 128, 12, 12) = onnx::Add(%151, %146), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]
#   %153 : Float(1, 128, 12, 12) = onnx::Relu(%152), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/ReLU[relu]
#   %154 : Dynamic = onnx::Pad[mode=constant, pads=[0, 0, 2, 2, 0, 0, 2, 2], value=0](%153), scope: CustomResnet/ResHead[reshead]/AvgPool2d[av_pool]
#   %155 : Float(1, 128, 2, 2) = onnx::AveragePool[kernel_shape=[8, 8], pads=[0, 0, 0, 0], strides=[6, 6]](%154), scope: CustomResnet/ResHead[reshead]/AvgPool2d[av_pool]
#   %156 : Dynamic = onnx::Constant[value=  -1  512 [ CPULongTensor{2} ]](), scope: CustomResnet/ResHead[reshead]
#   %157 : Float(1, 512) = onnx::Reshape(%155, %156), scope: CustomResnet/ResHead[reshead]
#   %158 : Float(1, 51) = onnx::Gemm[alpha=1, beta=1, broadcast=1, transB=1](%157, %97, %98), scope: CustomResnet/ResHead[reshead]/Linear[linear]
#   %159 : Dynamic = onnx::Constant[value= -1  51 [ CPULongTensor{2} ]](), scope: CustomResnet
#   %output1 : Float(1, 51) = onnx::Reshape(%158, %159), scope: CustomResnet
#   return (%output1);
# }

# %% [markdown]
# # Training Round Three (Test )

# %%
lr = 1e-3  
lr_array = np.array([lr/5,lr/3,lr])

for i in range(1,7):
    print (f'Run #{i}')
    epoch_count = i
    lr_list = train.set_lr_sched(epoch_count,mtrain.__len__()//batch_size,2.0)
    helper.lr_preview(lr_list)
    freeze = (i-1)*2
    if i == 4:
        freeze = 100
    train.one_run(train_dict,freeze,lr_list,lr_array)
# Out:
# Run #1
# Layer 0 : Grad:False
# Layer 1 : Grad:False
# Layer 2 : Grad:False
# Layer 3 : Grad:False
# Layer 4 : Grad:False
# Layer 5 : Grad:False
# train mse_loss: 0.026450252160429955   train point_loss: 0.024199558421969414
# test mse_loss: 0.024269431829452515   test point_loss: 0.022332116961479187
# Done
# Run #2
# Layer 0 : Grad:False
# Layer 1 : Grad:False
# Layer 2 : Grad:False
# Layer 3 : Grad:False
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fa17dc08ac8>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.02481352910399437   train point_loss: 0.023184943944215775
# test mse_loss: 0.021289115771651268   test point_loss: 0.02028040774166584
# Done
# Run #3
# Layer 0 : Grad:False
# Layer 1 : Grad:False
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fa17ff2dd30>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.024551041424274445   train point_loss: 0.022828588262200356
# test mse_loss: 0.020695792511105537   test point_loss: 0.020780084654688835
# Done
# Run #4
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.024909665808081627   train point_loss: 0.023308679461479187
# test mse_loss: 0.027658749371767044   test point_loss: 0.02410353347659111
# train mse_loss: 0.023859867826104164   train point_loss: 0.02226904407143593
# test mse_loss: 0.02038857340812683   test point_loss: 0.01973888650536537
# Done
# Run #5
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.024356119334697723   train point_loss: 0.022913245484232903
# test mse_loss: 0.0289547611027956   test point_loss: 0.02507764846086502
# train mse_loss: 0.024166475981473923   train point_loss: 0.022668253630399704
# test mse_loss: 0.026668880134820938   test point_loss: 0.025460785254836082
# train mse_loss: 0.0251288041472435   train point_loss: 0.023532256484031677
# test mse_loss: 0.022673647850751877   test point_loss: 0.022413931787014008
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fa1927ffc88>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 737, in answer_challenge
#     response = connection.recv_bytes(256)        # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# ConnectionResetError: [Errno 104] Connection reset by peer
# train mse_loss: 0.021630825474858284   train point_loss: 0.020836293697357178
# test mse_loss: 0.01970696821808815   test point_loss: 0.019059911370277405
# Done
# Run #6
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.024043094366788864   train point_loss: 0.022634143009781837
# test mse_loss: 0.02940051630139351   test point_loss: 0.02601533755660057
# train mse_loss: 0.023728061467409134   train point_loss: 0.022566214203834534
# test mse_loss: 0.027727436274290085   test point_loss: 0.025621118023991585
# train mse_loss: 0.02487250044941902   train point_loss: 0.023412736132740974
# test mse_loss: 0.021842412650585175   test point_loss: 0.02172086201608181
# train mse_loss: 0.021618112921714783   train point_loss: 0.0208121407777071
# test mse_loss: 0.02775934524834156   test point_loss: 0.02611340954899788
# train mse_loss: 0.025326091796159744   train point_loss: 0.02401060052216053
# test mse_loss: 0.026072055101394653   test point_loss: 0.02351291850209236
# train mse_loss: 0.023978358134627342   train point_loss: 0.02278846502304077
# test mse_loss: 0.021549539640545845   test point_loss: 0.0196407288312912
# train mse_loss: 0.021362410858273506   train point_loss: 0.020729728043079376
# test mse_loss: 0.01918361522257328   test point_loss: 0.01888384111225605
# train mse_loss: 0.019706010818481445   train point_loss: 0.019311822950839996
# test mse_loss: 0.01912141963839531   test point_loss: 0.018620720133185387
# Done

# %%
helper.view_predictions(res_net,train_data)
helper.export_onnx(res_net,'output/'+output_name+'run_3')
# Out:
# graph(%0 : Float(1, 3, 96, 96)
#       %1 : Float(64, 3, 7, 7)
#       %2 : Float(64)
#       %3 : Float(64)
#       %4 : Float(64)
#       %5 : Float(64)
#       %6 : Long()
#       %7 : Float(64, 64, 3, 3)
#       %8 : Float(64)
#       %9 : Float(64)
#       %10 : Float(64)
#       %11 : Float(64)
#       %12 : Long()
#       %13 : Float(64, 64, 3, 3)
#       %14 : Float(64)
#       %15 : Float(64)
#       %16 : Float(64)
#       %17 : Float(64)
#       %18 : Long()
#       %19 : Float(64, 64, 3, 3)
#       %20 : Float(64)
#       %21 : Float(64)
#       %22 : Float(64)
#       %23 : Float(64)
#       %24 : Long()
#       %25 : Float(64, 64, 3, 3)
#       %26 : Float(64)
#       %27 : Float(64)
#       %28 : Float(64)
#       %29 : Float(64)
#       %30 : Long()
#       %31 : Float(64, 64, 3, 3)
#       %32 : Float(64)
#       %33 : Float(64)
#       %34 : Float(64)
#       %35 : Float(64)
#       %36 : Long()
#       %37 : Float(64, 64, 3, 3)
#       %38 : Float(64)
#       %39 : Float(64)
#       %40 : Float(64)
#       %41 : Float(64)
#       %42 : Long()
#       %43 : Float(128, 64, 3, 3)
#       %44 : Float(128)
#       %45 : Float(128)
#       %46 : Float(128)
#       %47 : Float(128)
#       %48 : Long()
#       %49 : Float(128, 128, 3, 3)
#       %50 : Float(128)
#       %51 : Float(128)
#       %52 : Float(128)
#       %53 : Float(128)
#       %54 : Long()
#       %55 : Float(128, 64, 1, 1)
#       %56 : Float(128)
#       %57 : Float(128)
#       %58 : Float(128)
#       %59 : Float(128)
#       %60 : Long()
#       %61 : Float(128, 128, 3, 3)
#       %62 : Float(128)
#       %63 : Float(128)
#       %64 : Float(128)
#       %65 : Float(128)
#       %66 : Long()
#       %67 : Float(128, 128, 3, 3)
#       %68 : Float(128)
#       %69 : Float(128)
#       %70 : Float(128)
#       %71 : Float(128)
#       %72 : Long()
#       %73 : Float(128, 128, 3, 3)
#       %74 : Float(128)
#       %75 : Float(128)
#       %76 : Float(128)
#       %77 : Float(128)
#       %78 : Long()
#       %79 : Float(128, 128, 3, 3)
#       %80 : Float(128)
#       %81 : Float(128)
#       %82 : Float(128)
#       %83 : Float(128)
#       %84 : Long()
#       %85 : Float(128, 128, 3, 3)
#       %86 : Float(128)
#       %87 : Float(128)
#       %88 : Float(128)
#       %89 : Float(128)
#       %90 : Long()
#       %91 : Float(128, 128, 3, 3)
#       %92 : Float(128)
#       %93 : Float(128)
#       %94 : Float(128)
#       %95 : Float(128)
#       %96 : Long()
#       %97 : Float(51, 512)
#       %98 : Float(51)) {
#   %99 : Float(1, 64, 48, 48) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[2, 2]](%0, %1), scope: CustomResnet/Sequential[resnet]/Conv2d[0]
#   %100 : Float(1, 64, 48, 48) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%99, %2, %3, %4, %5), scope: CustomResnet/Sequential[resnet]/BatchNorm2d[1]
#   %101 : Float(1, 64, 48, 48) = onnx::Relu(%100), scope: CustomResnet/Sequential[resnet]/ReLU[2]
#   %102 : Float(1, 64, 24, 24) = onnx::MaxPool[kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%101), scope: CustomResnet/Sequential[resnet]/MaxPool2d[3]
#   %103 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%102, %7), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/Conv2d[conv1]
#   %104 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%103, %8, %9, %10, %11), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/BatchNorm2d[bn1]
#   %105 : Float(1, 64, 24, 24) = onnx::Relu(%104), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/ReLU[relu]
#   %106 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%105, %13), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/Conv2d[conv2]
#   %107 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%106, %14, %15, %16, %17), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/BatchNorm2d[bn2]
#   %108 : Float(1, 64, 24, 24) = onnx::Add(%107, %102), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]
#   %109 : Float(1, 64, 24, 24) = onnx::Relu(%108), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/ReLU[relu]
#   %110 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%109, %19), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/Conv2d[conv1]
#   %111 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%110, %20, %21, %22, %23), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/BatchNorm2d[bn1]
#   %112 : Float(1, 64, 24, 24) = onnx::Relu(%111), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/ReLU[relu]
#   %113 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%112, %25), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/Conv2d[conv2]
#   %114 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%113, %26, %27, %28, %29), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/BatchNorm2d[bn2]
#   %115 : Float(1, 64, 24, 24) = onnx::Add(%114, %109), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]
#   %116 : Float(1, 64, 24, 24) = onnx::Relu(%115), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/ReLU[relu]
#   %117 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%116, %31), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/Conv2d[conv1]
#   %118 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%117, %32, %33, %34, %35), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/BatchNorm2d[bn1]
#   %119 : Float(1, 64, 24, 24) = onnx::Relu(%118), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/ReLU[relu]
#   %120 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%119, %37), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/Conv2d[conv2]
#   %121 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%120, %38, %39, %40, %41), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/BatchNorm2d[bn2]
#   %122 : Float(1, 64, 24, 24) = onnx::Add(%121, %116), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]
#   %123 : Float(1, 64, 24, 24) = onnx::Relu(%122), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/ReLU[relu]
#   %124 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%123, %43), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Conv2d[conv1]
#   %125 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%124, %44, %45, %46, %47), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/BatchNorm2d[bn1]
#   %126 : Float(1, 128, 12, 12) = onnx::Relu(%125), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/ReLU[relu]
#   %127 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%126, %49), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Conv2d[conv2]
#   %128 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%127, %50, %51, %52, %53), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/BatchNorm2d[bn2]
#   %129 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%123, %55), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]
#   %130 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%129, %56, %57, %58, %59), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]
#   %131 : Float(1, 128, 12, 12) = onnx::Add(%128, %130), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]
#   %132 : Float(1, 128, 12, 12) = onnx::Relu(%131), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/ReLU[relu]
#   %133 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%132, %61), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/Conv2d[conv1]
#   %134 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%133, %62, %63, %64, %65), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/BatchNorm2d[bn1]
#   %135 : Float(1, 128, 12, 12) = onnx::Relu(%134), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/ReLU[relu]
#   %136 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%135, %67), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/Conv2d[conv2]
#   %137 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%136, %68, %69, %70, %71), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/BatchNorm2d[bn2]
#   %138 : Float(1, 128, 12, 12) = onnx::Add(%137, %132), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]
#   %139 : Float(1, 128, 12, 12) = onnx::Relu(%138), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/ReLU[relu]
#   %140 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%139, %73), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/Conv2d[conv1]
#   %141 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%140, %74, %75, %76, %77), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/BatchNorm2d[bn1]
#   %142 : Float(1, 128, 12, 12) = onnx::Relu(%141), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/ReLU[relu]
#   %143 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%142, %79), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/Conv2d[conv2]
#   %144 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%143, %80, %81, %82, %83), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/BatchNorm2d[bn2]
#   %145 : Float(1, 128, 12, 12) = onnx::Add(%144, %139), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]
#   %146 : Float(1, 128, 12, 12) = onnx::Relu(%145), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/ReLU[relu]
#   %147 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%146, %85), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/Conv2d[conv1]
#   %148 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%147, %86, %87, %88, %89), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/BatchNorm2d[bn1]
#   %149 : Float(1, 128, 12, 12) = onnx::Relu(%148), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/ReLU[relu]
#   %150 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%149, %91), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/Conv2d[conv2]
#   %151 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%150, %92, %93, %94, %95), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/BatchNorm2d[bn2]
#   %152 : Float(1, 128, 12, 12) = onnx::Add(%151, %146), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]
#   %153 : Float(1, 128, 12, 12) = onnx::Relu(%152), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/ReLU[relu]
#   %154 : Dynamic = onnx::Pad[mode=constant, pads=[0, 0, 2, 2, 0, 0, 2, 2], value=0](%153), scope: CustomResnet/ResHead[reshead]/AvgPool2d[av_pool]
#   %155 : Float(1, 128, 2, 2) = onnx::AveragePool[kernel_shape=[8, 8], pads=[0, 0, 0, 0], strides=[6, 6]](%154), scope: CustomResnet/ResHead[reshead]/AvgPool2d[av_pool]
#   %156 : Dynamic = onnx::Constant[value=  -1  512 [ CPULongTensor{2} ]](), scope: CustomResnet/ResHead[reshead]
#   %157 : Float(1, 512) = onnx::Reshape(%155, %156), scope: CustomResnet/ResHead[reshead]
#   %158 : Float(1, 51) = onnx::Gemm[alpha=1, beta=1, broadcast=1, transB=1](%157, %97, %98), scope: CustomResnet/ResHead[reshead]/Linear[linear]
#   %159 : Dynamic = onnx::Constant[value= -1  51 [ CPULongTensor{2} ]](), scope: CustomResnet
#   %output1 : Float(1, 51) = onnx::Reshape(%158, %159), scope: CustomResnet
#   return (%output1);
# }

# %% [markdown]
# # Training Round Four (Test )

# %%
lr = 1e-4  
lr_array = np.array([lr/5,lr/3,lr])

for i in range(1,7):
    print (f'Run #{i}')
    epoch_count = i
    lr_list = train.set_lr_sched(epoch_count,mtrain.__len__()//batch_size,2.0)
    helper.lr_preview(lr_list)

    freeze = 100
    train.one_run(train_dict,freeze,lr_list,lr_array)
# Out:
# Run #1
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.02054467238485813   train point_loss: 0.01993797905743122
# test mse_loss: 0.018406203016638756   test point_loss: 0.018269089981913567
# Done
# Run #2
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fa192a27160>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
# train mse_loss: 0.019519373774528503   train point_loss: 0.01929992251098156
# test mse_loss: 0.019397180527448654   test point_loss: 0.019475560635328293
# Done
# Run #3
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fa19284f208>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
# train mse_loss: 0.019584085792303085   train point_loss: 0.01930776797235012
# test mse_loss: 0.0197020024061203   test point_loss: 0.018915850669145584
# Done
# Run #4
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.019363289698958397   train point_loss: 0.01925298385322094
# test mse_loss: 0.017741316929459572   test point_loss: 0.01818590611219406
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fa1926a4b00>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
# train mse_loss: 0.019161004573106766   train point_loss: 0.019084425643086433
# test mse_loss: 0.01921108551323414   test point_loss: 0.018597349524497986
# Done
# Run #5
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.01907177083194256   train point_loss: 0.018967637792229652
# test mse_loss: 0.018278274685144424   test point_loss: 0.018359225243330002
# train mse_loss: 0.018904034048318863   train point_loss: 0.01885315217077732
# test mse_loss: 0.018617864698171616   test point_loss: 0.018659863620996475
# train mse_loss: 0.01885143667459488   train point_loss: 0.01890670694410801
# test mse_loss: 0.01782999560236931   test point_loss: 0.01795209012925625
# Exception ignored in: <bound method _DataLoaderIter.__del__ of <torch.utils.data.dataloader._DataLoaderIter object at 0x7fa19287bf28>>
# Traceback (most recent call last):
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 399, in __del__
#     self._shutdown_workers()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 378, in _shutdown_workers
#     self.worker_result_queue.get()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/queues.py", line 337, in get
#     return _ForkingPickler.loads(res)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py", line 151, in rebuild_storage_fd
#     fd = df.detach()
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 493, in Client
#     answer_challenge(c, authkey)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 732, in answer_challenge
#     message = connection.recv_bytes(256)         # reject large message
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/paperspace/anaconda3/envs/torch1cv/lib/python3.6/multiprocessing/connection.py", line 383, in _recv
#     raise EOFError
# EOFError:
# train mse_loss: 0.018415167927742004   train point_loss: 0.018528953194618225
# test mse_loss: 0.01754346489906311   test point_loss: 0.017410917207598686
# Done
# Run #6
# Layer 0 : Grad:True
# Layer 1 : Grad:True
# Layer 2 : Grad:True
# Layer 3 : Grad:True
# Layer 4 : Grad:True
# Layer 5 : Grad:True
# train mse_loss: 0.018550075590610504   train point_loss: 0.01858649030327797
# test mse_loss: 0.018450064584612846   test point_loss: 0.01821567863225937
# train mse_loss: 0.01843770034611225   train point_loss: 0.018447693437337875
# test mse_loss: 0.017799952998757362   test point_loss: 0.01868870109319687
# train mse_loss: 0.018446819856762886   train point_loss: 0.018525786697864532
# test mse_loss: 0.017769830301404   test point_loss: 0.0177347119897604
# train mse_loss: 0.018262159079313278   train point_loss: 0.018272489309310913
# test mse_loss: 0.018057676032185555   test point_loss: 0.018602214753627777
# train mse_loss: 0.018409566953778267   train point_loss: 0.01847141794860363
# test mse_loss: 0.018392838537693024   test point_loss: 0.018344955518841743
# train mse_loss: 0.018012594431638718   train point_loss: 0.018134193494915962
# test mse_loss: 0.01721920631825924   test point_loss: 0.017230847850441933
# train mse_loss: 0.017839694395661354   train point_loss: 0.017979983240365982
# test mse_loss: 0.017425281926989555   test point_loss: 0.017257194966077805
# train mse_loss: 0.017505113035440445   train point_loss: 0.017925694584846497
# test mse_loss: 0.017050571739673615   test point_loss: 0.017621317878365517
# Done

# %%
helper.view_predictions(res_net,train_data)
helper.export_onnx(res_net,'output/'+output_name+'run_4')
# Out:
# graph(%0 : Float(1, 3, 96, 96)
#       %1 : Float(64, 3, 7, 7)
#       %2 : Float(64)
#       %3 : Float(64)
#       %4 : Float(64)
#       %5 : Float(64)
#       %6 : Long()
#       %7 : Float(64, 64, 3, 3)
#       %8 : Float(64)
#       %9 : Float(64)
#       %10 : Float(64)
#       %11 : Float(64)
#       %12 : Long()
#       %13 : Float(64, 64, 3, 3)
#       %14 : Float(64)
#       %15 : Float(64)
#       %16 : Float(64)
#       %17 : Float(64)
#       %18 : Long()
#       %19 : Float(64, 64, 3, 3)
#       %20 : Float(64)
#       %21 : Float(64)
#       %22 : Float(64)
#       %23 : Float(64)
#       %24 : Long()
#       %25 : Float(64, 64, 3, 3)
#       %26 : Float(64)
#       %27 : Float(64)
#       %28 : Float(64)
#       %29 : Float(64)
#       %30 : Long()
#       %31 : Float(64, 64, 3, 3)
#       %32 : Float(64)
#       %33 : Float(64)
#       %34 : Float(64)
#       %35 : Float(64)
#       %36 : Long()
#       %37 : Float(64, 64, 3, 3)
#       %38 : Float(64)
#       %39 : Float(64)
#       %40 : Float(64)
#       %41 : Float(64)
#       %42 : Long()
#       %43 : Float(128, 64, 3, 3)
#       %44 : Float(128)
#       %45 : Float(128)
#       %46 : Float(128)
#       %47 : Float(128)
#       %48 : Long()
#       %49 : Float(128, 128, 3, 3)
#       %50 : Float(128)
#       %51 : Float(128)
#       %52 : Float(128)
#       %53 : Float(128)
#       %54 : Long()
#       %55 : Float(128, 64, 1, 1)
#       %56 : Float(128)
#       %57 : Float(128)
#       %58 : Float(128)
#       %59 : Float(128)
#       %60 : Long()
#       %61 : Float(128, 128, 3, 3)
#       %62 : Float(128)
#       %63 : Float(128)
#       %64 : Float(128)
#       %65 : Float(128)
#       %66 : Long()
#       %67 : Float(128, 128, 3, 3)
#       %68 : Float(128)
#       %69 : Float(128)
#       %70 : Float(128)
#       %71 : Float(128)
#       %72 : Long()
#       %73 : Float(128, 128, 3, 3)
#       %74 : Float(128)
#       %75 : Float(128)
#       %76 : Float(128)
#       %77 : Float(128)
#       %78 : Long()
#       %79 : Float(128, 128, 3, 3)
#       %80 : Float(128)
#       %81 : Float(128)
#       %82 : Float(128)
#       %83 : Float(128)
#       %84 : Long()
#       %85 : Float(128, 128, 3, 3)
#       %86 : Float(128)
#       %87 : Float(128)
#       %88 : Float(128)
#       %89 : Float(128)
#       %90 : Long()
#       %91 : Float(128, 128, 3, 3)
#       %92 : Float(128)
#       %93 : Float(128)
#       %94 : Float(128)
#       %95 : Float(128)
#       %96 : Long()
#       %97 : Float(51, 512)
#       %98 : Float(51)) {
#   %99 : Float(1, 64, 48, 48) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[2, 2]](%0, %1), scope: CustomResnet/Sequential[resnet]/Conv2d[0]
#   %100 : Float(1, 64, 48, 48) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%99, %2, %3, %4, %5), scope: CustomResnet/Sequential[resnet]/BatchNorm2d[1]
#   %101 : Float(1, 64, 48, 48) = onnx::Relu(%100), scope: CustomResnet/Sequential[resnet]/ReLU[2]
#   %102 : Float(1, 64, 24, 24) = onnx::MaxPool[kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%101), scope: CustomResnet/Sequential[resnet]/MaxPool2d[3]
#   %103 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%102, %7), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/Conv2d[conv1]
#   %104 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%103, %8, %9, %10, %11), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/BatchNorm2d[bn1]
#   %105 : Float(1, 64, 24, 24) = onnx::Relu(%104), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/ReLU[relu]
#   %106 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%105, %13), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/Conv2d[conv2]
#   %107 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%106, %14, %15, %16, %17), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/BatchNorm2d[bn2]
#   %108 : Float(1, 64, 24, 24) = onnx::Add(%107, %102), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]
#   %109 : Float(1, 64, 24, 24) = onnx::Relu(%108), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[0]/ReLU[relu]
#   %110 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%109, %19), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/Conv2d[conv1]
#   %111 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%110, %20, %21, %22, %23), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/BatchNorm2d[bn1]
#   %112 : Float(1, 64, 24, 24) = onnx::Relu(%111), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/ReLU[relu]
#   %113 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%112, %25), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/Conv2d[conv2]
#   %114 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%113, %26, %27, %28, %29), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/BatchNorm2d[bn2]
#   %115 : Float(1, 64, 24, 24) = onnx::Add(%114, %109), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]
#   %116 : Float(1, 64, 24, 24) = onnx::Relu(%115), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[1]/ReLU[relu]
#   %117 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%116, %31), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/Conv2d[conv1]
#   %118 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%117, %32, %33, %34, %35), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/BatchNorm2d[bn1]
#   %119 : Float(1, 64, 24, 24) = onnx::Relu(%118), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/ReLU[relu]
#   %120 : Float(1, 64, 24, 24) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%119, %37), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/Conv2d[conv2]
#   %121 : Float(1, 64, 24, 24) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%120, %38, %39, %40, %41), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/BatchNorm2d[bn2]
#   %122 : Float(1, 64, 24, 24) = onnx::Add(%121, %116), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]
#   %123 : Float(1, 64, 24, 24) = onnx::Relu(%122), scope: CustomResnet/Sequential[resnet]/Sequential[4]/BasicBlock[2]/ReLU[relu]
#   %124 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%123, %43), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Conv2d[conv1]
#   %125 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%124, %44, %45, %46, %47), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/BatchNorm2d[bn1]
#   %126 : Float(1, 128, 12, 12) = onnx::Relu(%125), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/ReLU[relu]
#   %127 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%126, %49), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Conv2d[conv2]
#   %128 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%127, %50, %51, %52, %53), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/BatchNorm2d[bn2]
#   %129 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%123, %55), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]
#   %130 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%129, %56, %57, %58, %59), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]
#   %131 : Float(1, 128, 12, 12) = onnx::Add(%128, %130), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]
#   %132 : Float(1, 128, 12, 12) = onnx::Relu(%131), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[0]/ReLU[relu]
#   %133 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%132, %61), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/Conv2d[conv1]
#   %134 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%133, %62, %63, %64, %65), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/BatchNorm2d[bn1]
#   %135 : Float(1, 128, 12, 12) = onnx::Relu(%134), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/ReLU[relu]
#   %136 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%135, %67), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/Conv2d[conv2]
#   %137 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%136, %68, %69, %70, %71), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/BatchNorm2d[bn2]
#   %138 : Float(1, 128, 12, 12) = onnx::Add(%137, %132), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]
#   %139 : Float(1, 128, 12, 12) = onnx::Relu(%138), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[1]/ReLU[relu]
#   %140 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%139, %73), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/Conv2d[conv1]
#   %141 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%140, %74, %75, %76, %77), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/BatchNorm2d[bn1]
#   %142 : Float(1, 128, 12, 12) = onnx::Relu(%141), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/ReLU[relu]
#   %143 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%142, %79), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/Conv2d[conv2]
#   %144 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%143, %80, %81, %82, %83), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/BatchNorm2d[bn2]
#   %145 : Float(1, 128, 12, 12) = onnx::Add(%144, %139), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]
#   %146 : Float(1, 128, 12, 12) = onnx::Relu(%145), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[2]/ReLU[relu]
#   %147 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%146, %85), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/Conv2d[conv1]
#   %148 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%147, %86, %87, %88, %89), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/BatchNorm2d[bn1]
#   %149 : Float(1, 128, 12, 12) = onnx::Relu(%148), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/ReLU[relu]
#   %150 : Float(1, 128, 12, 12) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%149, %91), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/Conv2d[conv2]
#   %151 : Float(1, 128, 12, 12) = onnx::BatchNormalization[epsilon=1e-05, is_test=1, momentum=1](%150, %92, %93, %94, %95), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/BatchNorm2d[bn2]
#   %152 : Float(1, 128, 12, 12) = onnx::Add(%151, %146), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]
#   %153 : Float(1, 128, 12, 12) = onnx::Relu(%152), scope: CustomResnet/Sequential[resnet]/Sequential[5]/BasicBlock[3]/ReLU[relu]
#   %154 : Dynamic = onnx::Pad[mode=constant, pads=[0, 0, 2, 2, 0, 0, 2, 2], value=0](%153), scope: CustomResnet/ResHead[reshead]/AvgPool2d[av_pool]
#   %155 : Float(1, 128, 2, 2) = onnx::AveragePool[kernel_shape=[8, 8], pads=[0, 0, 0, 0], strides=[6, 6]](%154), scope: CustomResnet/ResHead[reshead]/AvgPool2d[av_pool]
#   %156 : Dynamic = onnx::Constant[value=  -1  512 [ CPULongTensor{2} ]](), scope: CustomResnet/ResHead[reshead]
#   %157 : Float(1, 512) = onnx::Reshape(%155, %156), scope: CustomResnet/ResHead[reshead]
#   %158 : Float(1, 51) = onnx::Gemm[alpha=1, beta=1, broadcast=1, transB=1](%157, %97, %98), scope: CustomResnet/ResHead[reshead]/Linear[linear]
#   %159 : Dynamic = onnx::Constant[value= -1  51 [ CPULongTensor{2} ]](), scope: CustomResnet
#   %output1 : Float(1, 51) = onnx::Reshape(%158, %159), scope: CustomResnet
#   return (%output1);
# }
